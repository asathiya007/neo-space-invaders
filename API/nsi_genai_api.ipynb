# %% [markdown]
# # Neo Space Invaders Generative AI API
#
# Neo Space Invaders uses AI-generated content for its backgrounds and sprites. This API runs Stable Diffusion 2, which is used to generate that content.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers (to revision main) to /tmp/pip-install-7ua4brpk/diffusers_827b909b463e489b9c433fa024762f0e
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-install-7ua4brpk/diffusers_827b909b463e489b9c433fa024762f0e
#   Resolved https://github.com/huggingface/diffusers to commit 3c8b67b3711b668a6e7867e08b54280e51454eb5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 49.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 124.0 MB/s eta 0:00:00
# ...

# %%
# !ngrok config add-authtoken <AUTH TOKEN>
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !python nsi_genai_api.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   0% 0/50 [00:00<?, ?it/s]
#   2% 1/50 [00:00<00:23,  2.13it/s]
#   4% 2/50 [00:00<00:19,  2.51it/s]
#   6% 3/50 [00:01<00:17,  2.69it/s]
#   8% 4/50 [00:01<00:16,  2.78it/s]
#  10% 5/50 [00:01<00:15,  2.83it/s]
#  12% 6/50 [00:02<00:15,  2.85it/s]
#  14% 7/50 [00:02<00:14,  2.87it/s]
#  16% 8/50 [00:02<00:14,  2.87it/s]
#  18% 9/50 [00:03<00:14,  2.87it/s]
#  20% 10/50 [00:03<00:13,  2.88it/s]
#  22% 11/50 [00:03<00:13,  2.88it/s]
#  24% 12/50 [00:04<00:13,  2.89it/s]
#  26% 13/50 [00:04<00:12,  2.89it/s]
#  28% 14/50 [00:04<00:12,  2.90it/s]
#  30% 15/50 [00:05<00:12,  2.89it/s]
#  32% 16/50 [00:05<00:11,  2.89it/s]
#  34% 17/50 [00:05<00:11,  2.89it/s]
#  36% 18/50 [00:06<00:11,  2.89it/s]
#  38% 19/50 [00:06<00:10,  2.90it/s]
#  40% 20/50 [00:07<00:10,  2.90it/s]
#  42% 21/50 [00:07<00:09,  2.90it/s]
#  44% 22/50 [00:07<00:09,  2.90it/s]
#  46% 23/50 [00:08<00:09,  2.89it/s]
#  48% 24/50 [00:08<00:08,  2.89it/s]
# ...
